# %%
#orginal file:
#https://colab.research.google.com/drive/1nBSyakVz1hwk8c9ZIoSAMkcj0yDhMOP8

# %%
# !python train_model.py

# %%
import os
print(os.listdir())

# %%
print(os.listdir())

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
DATASET_PATH = "/content/drive/MyDrive/brain_tumor_dataset"

# %%
import os
print(os.listdir("/content/drive/MyDrive"))

# %%
import os
print(os.listdir("/content/drive/MyDrive"))

# %%
for root, dirs, files in os.walk("/content/drive"):
    if "brain_tumor_dataset" in root:
        print("FOUND HERE:", root)

# %%
DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"

# %%
import os
print(os.listdir("/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"))

# %%
DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"

# %%
import os
print(os.listdir(DATASET_PATH))

# %%
# !python train_model.py

# %%
DATASET_PATH = "./brain_tumor_dataset"

# %%
DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"

# %%
import os
print(os.listdir("/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"))

# %%
# !python /content/train_model.py

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

for root, dirs, files in os.walk("/content/drive/MyDrive"):
    if "yes" in dirs and "no" in dirs:
        print("FOUND DATASET AT:", root)

# %%
DATASET_PATH = "./brain_tumor_dataset"

# %%
DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"

# %%
import os
print(os.listdir("/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"))

# %%
# !python /content/train_model.py

# %%
# !grep -n "DATASET_PATH" /content/train_model.py

# %%
with open("/content/train_model.py", "r") as f:
    code = f.read()

code = code.replace("./brain_tumor_dataset", "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset")

with open("/content/train_model.py", "w") as f:
    f.write(code)

print("DONE FIXING PATH")

# %%
# !grep -n "brain_tumor_dataset" /content/train_model.py

# %%
print("DATASET_PATH =", DATASET_PATH)

# %%
DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"

# %%
print(DATASET_PATH)

# %%
import os

DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"

tumor_path = os.path.join(DATASET_PATH, "yes")
no_path = os.path.join(DATASET_PATH, "no")

print("YES exists:", os.path.exists(tumor_path))
print("NO exists:", os.path.exists(no_path))

print("Dataset root:", os.listdir(DATASET_PATH))

# %%
# !python /content/train_model.py

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/train_model.py" /content/

# %%
DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"

# %%
print(DATASET_PATH)

# %%
import os

DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"

tumor_path = os.path.join(DATASET_PATH, "yes")
no_path = os.path.join(DATASET_PATH, "no")

print("YES exists:", os.path.exists(tumor_path))
print("NO exists:", os.path.exists(no_path))

print("Dataset root:", os.listdir(DATASET_PATH))

# %%
# !python /content/train_model.py

# %%
import os
print(os.listdir("/content"))

# %%
data_path = "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"

print(os.listdir(data_path))
print("YES exists:", os.path.exists(data_path + "/yes"))
print("NO exists:", os.path.exists(data_path + "/no"))

# %%
file_path = "/content/train_model.py"

with open(file_path, "r") as f:
    code = f.read()


code = code.replace("./brain_tumor_dataset", "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset")

with open(file_path, "w") as f:
    f.write(code)

print("✅ PATH FIXED SUCCESSFULLY")

# %%
# !grep -n "brain_tumor_dataset" /content/train_model.py

# %%
# !rm /content/train_model.py

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/train_model.py" /content/

# %%
# !grep -n "DATASET_PATH" /content/train_model.py

# %%
file_path = "/content/train_model.py"

with open(file_path, "r") as f:
    code = f.read()


code = code.replace(
    "./brain_tumor_dataset",
    "/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset"
)

with open(file_path, "w") as f:
    f.write(code)

print("DONE FIXING PATH")

# %%
# !grep -n "DATASET_PATH" /content/train_model.py

# %%
# !python /content/train_model.py

# %%
MODEL_SAVE_PATH = "./brain_tumor_model.h5"

# %%
# !find /content -name "*.h5"

# %%
# !ls

# %%
from google.colab import files
files.upload()

# %%
# !ls

# %%
# !ls
# Out:
# sample_data  train_model.py

# %%
# !python train_model.py
# Out:
# 2026-05-01 18:49:24.832845: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version: 2.20.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ...
# BRAIN TUMOR DETECTION – CNN TRAINING
# CSDS4208 – Deep Learning Project
# ...
#
# [1/6] Loading dataset...
# Traceback (most recent call last):
#   File "/content/train_model.py", line 433, in <module>
#     model, history, metrics = main()
#                               ^^^^^^
#   File "/content/train_model.py", line 353, in main
#     X, y = load_dataset(DATASET_PATH)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/train_model.py", line 60, in load_dataset
#     for img_file in os.listdir(tumor_path):
#                     ^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/archive/brain_tumor_dataset
# Out:
# ls: cannot access '/content/drive/MyDrive/Colab Notebooks/archive/brain_tumor_dataset': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
# 'Colab Notebooks'  'هذاتكمله سؤال.gsheet'

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# archive  brain_tumor_dataset  Project.ipynb  train_model.py

# %%
DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/brain_tumor_dataset"

# %%
import os
print(os.listdir(DATASET_PATH))
# Out:
# ['yes', 'no']

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks"
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !python train_model.py
# Out:
# 2026-05-01 18:54:49.208308: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-01 18:54:49.281754: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version: 2.20.0
# 2026-05-01 18:54:52.575486: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# GPU Available: []
# ...
# BRAIN TUMOR DETECTION – CNN TRAINING
# CSDS4208 – Deep Learning Project
# ...
#
# [1/6] Loading dataset...
#
# Dataset loaded successfully!
# Total images: 253
# Tumor images: 155
# No Tumor images: 98
# Image shape: (224, 224, 3)
#
# [2/6] Visualizing sample images...
# Figure(1500x600)
# ...

# %%
# !cp brain_tumor_model.h5 "/content/drive/MyDrive/"
# Out:
# cp: cannot stat 'brain_tumor_model.h5': No such file or directory

# %%
# !ls
# Out:
# sample_data

# %%
# !cp brain_tumor_model.h5 "/content/drive/MyDrive/"
# Out:
# cp: cannot stat 'brain_tumor_model.h5': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
#  brain_tumor_model.h5  'Colab Notebooks'  'هذاتكمله سؤال.gsheet'

# %%
# !ls "/content/drive/MyDrive/brain_tumor_model.h5"
# Out:
# /content/drive/MyDrive/brain_tumor_model.h5

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks"
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !python train_model.py
# Out:
# 2026-05-01 21:47:46.126393: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-01 21:47:46.222302: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version: 2.20.0
# 2026-05-01 21:47:49.603354: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# GPU Available: []
# ...
# BRAIN TUMOR DETECTION – CNN TRAINING
# CSDS4208 – Deep Learning Project
# ...
#
# [1/6] Loading dataset...
#
# Dataset loaded successfully!
# Total images: 253
# Tumor images: 155
# No Tumor images: 98
# Image shape: (224, 224, 3)
#
# [2/6] Visualizing sample images...
# Figure(1500x600)
# ...
